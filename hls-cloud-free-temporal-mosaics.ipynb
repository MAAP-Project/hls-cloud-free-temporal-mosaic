# %% [markdown]
# # HLS Cloud-Free Temporal Mosaic job enumeration
#
# The product contract is one native HLS tile, one calendar interval, and `lower-median-v1`. The process reads both `HLSL30_2.0` and `HLSS30_2.0`, keeps the full native footprint, and writes one STAC item.
#
# This notebook discovers observed tiles from the HLS STAC GeoParquet archive for a geographic AOI, then submits one job per tile/month. It does not construct an arbitrary projected pixel grid.

# %%
from datetime import UTC, datetime, timedelta

from maap.maap import MAAP
from rustac import DuckdbClient

from main import hls_geoparquet_hrefs, hls_item_tile_id

COLLECTIONS = ("HLSL30_2.0", "HLSS30_2.0")
client = DuckdbClient()

maap = MAAP()

# %% [markdown]
# ## Discover tiles from an AOI
#
# The archive is partitioned by year and month, so the helper queries exact monthly parquet HREFs. It accepts STAC `bbox` and datetime filters. A service that supports exact polygon intersection can use `intersects` instead. With bbox-only search, the result is a candidate set and can include neighboring tiles; filter candidates with the AOI polygon before submitting jobs. The IDs below are deduplicated and sorted, so they represent tiles with observations rather than all theoretical MGRS tiles.

# %%
aoi_bbox = (-93.8, 44.5, -82.5, 50.2)
overall_start = datetime(2026, 5, 1, tzinfo=UTC)
overall_end = datetime(2026, 8, 31, tzinfo=UTC)
tile_ids = set()

for collection in COLLECTIONS:
    for href in hls_geoparquet_hrefs(collection, overall_start, overall_end):
        items = client.search(
            href,
            bbox=aoi_bbox,
            datetime=f"{overall_start.isoformat()}/{overall_end.isoformat()}",
            fields=["id", "datetime"],
        )
        tile_ids.update(
            tile_id
            for item in items
            if (tile_id := hls_item_tile_id(item.get("id", "")))
        )

tile_ids = sorted(tile_ids)
tile_ids
# Out:
# ['T15TVK',
#  'T15TVL',
#  'T15TVM',
#  'T15TVN',
#  'T15TWK',
#  'T15TWL',
#  'T15TWM',
#  'T15TWN',
#  'T15TXK',
#  'T15TXL',
#  'T15TXM',
#  'T15TXN',
#  'T15TYK',
#  'T15TYL',
#  'T15TYM',
#  'T15TYN',
#  'T15UVP',
#  'T15UVQ',
#  'T15UVR',
#  'T15UWP',
#  'T15UWQ',
#  'T15UWR',
#  'T15UXP',
#  'T15UXQ',
#  'T15UXR',
#  'T15UYP',
#  'T15UYQ',
#  'T15UYR',
#  'T16TCQ',
#  'T16TCR',
#  'T16TCS',
#  'T16TCT',
#  'T16TDQ',
#  'T16TDR',
#  'T16TDS',
#  'T16TDT',
#  'T16TEQ',
#  'T16TER',
#  'T16TES',
#  'T16TET',
#  'T16TFQ',
#  'T16TFR',
#  'T16TFS',
#  'T16TFT',
#  'T16TGQ',
#  'T16TGR',
#  'T16TGS',
#  'T16TGT',
#  'T16UCA',
#  'T16UCU',
#  'T16UCV',
#  'T16UDA',
#  'T16UDU',
#  'T16UDV',
#  'T16UEA',
#  'T16UEU',
#  'T16UEV',
#  'T16UFA',
#  'T16UFU',
#  'T16UFV',
#  'T16UGA',
#  'T16UGU',
#  'T16UGV',
#  'T17TLK',
#  'T17TLL',
#  'T17TLM',
#  'T17TLN',
#  'T17ULP',
#  'T17ULQ',
#  'T17ULR']

# %% [markdown]
# Some tile/month combinations can have no observations even when the tile appeared in the overall AOI interval. The job reports that condition clearly. Each output uses the full native HLS footprint, including overlap; downstream reprojection and mosaicking across tile footprints is a separate operation.

# %%
response = maap.list_algorithms()
response.raise_for_status()
process_id = next(
    process["processID"]
    for process in response.json()["processes"]
    if process["title"] == "HLS Cloud-Free Temporal Mosaic"
    # x-release-please-start-version
    and process["version"] == "0.4.2"
    # x-release-please-end-version
)


def generate_job_defs():
    month_start = overall_start
    while month_start < overall_end:
        next_month = (month_start.replace(day=28) + timedelta(days=4)).replace(day=1)
        for i, tile_id in enumerate(tile_ids):
            yield {
                "inputs": {
                    "start_datetime": month_start.strftime("%Y-%m-%dT00:00:00Z"),
                    "end_datetime": (next_month - timedelta(microseconds=1)).strftime(
                        "%Y-%m-%dT23:59:59Z"
                    ),
                    "tile_id": tile_id,
                },
                "tag": "group-1" if not i % 2 else "group-2",
            }
        month_start = next_month


job_defs = generate_job_defs()

# %%
job_def = next(job_defs)
job_def
# Out:
# {'inputs': {'start_datetime': '2026-05-01T00:00:00Z',
#   'end_datetime': '2026-05-31T23:59:59Z',
#   'tile_id': 'T15TVK'},
#  'tag': 'group-1'}

# %%
response = maap.submit_job(
    process_id=process_id,
    queue="maap-dps-worker-32gb",
    **job_def,
)
response.raise_for_status()

# %%
response.json()

# %%
job_defs = list(job_defs)
len(job_defs)
# Out:
# 279

# %%
for job_def in job_defs:
    response = maap.submit_job(
        process_id=process_id,
        queue="maap-dps-worker-16gb",
        **job_def,
    )
    response.raise_for_status()
